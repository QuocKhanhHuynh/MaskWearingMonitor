# %%
import cv2

from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/MyDrive/TGMT/project1
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/TGMT/project1

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.5/756.5 kB 7.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="https://luhanhvietnam.com.vn/du-lich/vnt_upload/news/06_2021/net-van-hoa-dac-trung-cua-sai-gon-con-nguoi.png"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 5, in <module>
#     from ultralytics.cfg import entrypoint
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/__init__.py", line 5, in <module>
#     from ultralytics.data.explorer.explorer import Explorer
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/data/__init__.py", line 3, in <module>
#     from .base import BaseDataset
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/data/base.py", line 15, in <module>
#     from torch.utils.data import Dataset
#   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 237, in <module>
#     from torch._C import *  # noqa: F403
# KeyboardInterrupt
# ^C

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=./data/coco128.yaml batch=16 epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
yolo export model="./content/drive/MyDrive/TGMT/project1/runs/detect/train4/weights/best.pt" format=tflite
# Out:
#   File "<ipython-input-4-ff9981d25002>", line 1
#     yolo export model="./content/drive/MyDrive/TGMT/project1/runs/detect/train4/weights/best.pt" format=tflite
#          ^
# SyntaxError: invalid syntax
